# %%
import pandas as pd
from langchain_ollama import OllamaLLM

llm = OllamaLLM(model="llama3.2")

# %%
df = pd.read_csv('prospectuses_data.csv')

# create a df copy with rows that do not hace "failed parsing" in the Section ID column
df = df[df['Section ID'] != "failed parsing"]
df.head(2)
# Out:
#    Prospectus ID Original Filename Section ID Section Title Subsection ID  \
# 3              4  FR0014001YE4.pdf          1  RISK FACTORS           1.1
# 4              4  FR0014001YE4.pdf          1  RISK FACTORS           1.2
#
#                                     Subsection Title Subsubsection ID  \
# 3                     1. Risks related to the Issuer            1.1.1
# 4  2. Risks related to the Bonds 2.1 Risks relati...            1.2.1
#
#                                  Subsubsection Title  \
# 3                                                NaN
# 4  2.1.1 The Bonds may be redeemed prior to maturity
#
#                                   Subsubsection Text  Market Dynamics - a  \
# 3  Risk factors relating to the Issuer and the Gr...                  NaN
# 4  The Issuer reserves the right to purchase Bond...                  NaN
#
#    Market Dynamics - b  Market Dynamics - c  LLM Answer  Evidence Text  \
# 3                  NaN                  NaN         NaN            NaN
# 4                  NaN                  NaN         NaN            NaN
#
#   Parsing Error
# 3           NaN
# 4           NaN

# %% [markdown]
# ### System Prompt
# You are an expert in analyzing bond prospectuses and identifying specific risk factors. Provide clear "Yes" or "No" answers to questions.

# %% [markdown]
# ### User Prompt
# Given the following excerpt from a bond prospectus:
#
# Title: [Subsubsection Title]
#
# Text: [Subsubsection Text]
#
# Please determine whether the text indicates the presence of the following characteristics. For each, answer "Yes" or "No".
#
# a. Exposure to cyclical products
#
# b. Impact of demographic and structural trends
#
# c. Seasonal industry volatility
#
# Please provide your answer in the following JSON format:
#
# {
#   "a": "Yes" or "No",
#   "b": "Yes" or "No",
#   "c": "Yes" or "No"
# }

# %%
def analyze_prospectus_row(row):
    # System and user prompts
    system_prompt = "You are an expert in analyzing bond prospectuses and identifying specific risk factors. Provide clear 'Yes' or 'No' answers to questions."
    
    # Format the user prompt using the row's data
    prompt = f"""
    Given the following excerpt from a bond prospectus: {row['Subsubsection Title']} \n {row['Subsubsection Text']}

    Please determine whether the text indicates a risk of exposure to cyclical products. For each, answer "Yes" or "No".

    a. Exposure to cyclical products

    b. Impact of demographic and structural trends

    c. Seasonal industry volatility

    Please provide your answer in the following JSON format:

    {{
      "a": "Yes" or "No",
      "b": "Yes" or "No",
      "c": "Yes" or "No"
    }}
    """
    # Run the prompt through the model
    response = llm(prompt=prompt)           
    
    # Return response as a dictionary for easy insertion into DataFrame
    return response

# %%
# create a copy of df with only the first 10 rows
df_subset = df.head(10)

# %%
# Apply the function row by row and store results in a new DataFrame column
df['analysis'] = df.apply(analyze_prospectus_row, axis=1)
df[['Subsubsection Title', 'Subsubsection Text', 'analysis']].head(2)
# Out:
#                                  Subsubsection Title  \
# 3                                                NaN
# 4  2.1.1 The Bonds may be redeemed prior to maturity
#
#                                   Subsubsection Text  \
# 3  Risk factors relating to the Issuer and the Gr...
# 4  The Issuer reserves the right to purchase Bond...
#
#                                             analysis
# 3  Based on the provided excerpt, here is the det...
# 4  Here is the response in JSON format:\n\n{\n  "...

# %%
df['analysis'].values
# Out:
# array(['Based on the provided excerpt, here is the determination of risk factors related to cyclical products and other industry characteristics:\n\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "No"\n}',
#        'Here is the response in JSON format:\n\n{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}',
#        '{\n  "a": "No",\n  "b": "No",\n  "c": "Yes"\n}',
#        '{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}',
#        'Here is the response in the requested JSON format:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "No"\n}',
#        'Given the excerpt, here is the response in the requested JSON format:\n\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "No"\n}',
#        '{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}',
#        'Based on the provided excerpt, here is the determination of risks related to cyclical products and other factors:\n\n\n{\n  "a": "Yes",\n  "b": "No",\n  "c": "No"\n}',
#        'Based on the provided excerpt, I would answer as follows:\n\n{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}\n\nThe text does not indicate any risk of exposure to cyclical products, impact of demographic and structural trends, or seasonal industry volatility. The risks mentioned are related to currency conversions due to exchange rates and exchange controls, which is more related to macroeconomic factors rather than the inherent characteristics of a product.',
#        'Based on the provided excerpt, here is the answer in JSON format:\n\n{\n  "a": "Yes",\n  "b": "No",\n  "c": "No"\n}\n\nExplanation:\n\n* a. Yes: The text mentions that the Joint Lead Managers and their affiliates actively trade debt and equity securities (or related derivative securities) for their own account, which could expose them to cyclical products.\n* b. No: There is no mention of demographic or structural trends in the excerpt.\n* c. No: There is no indication of seasonal industry volatility in the excerpt.',
#        '{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}',
#        'Based on the provided excerpt, my answers are:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "Yes"\n}\n\nHere\'s why:\n\n* a. Exposure to cyclical products: There is no mention of cyclical products in the text.\n* b. Impact of demographic and structural trends: The text mentions "demographic and structural trends" as a risk factor, indicating that the issuer believes such factors may affect its ability to fulfil its obligations under the bonds. Therefore, I answered "Yes".\n* c. Seasonal industry volatility: While there is no explicit mention of seasonal industry volatility, the term "Seasonal industry volatility" is defined in the "Terms and Conditions of the 2024 Bonds" and "Terms and Conditions of the 2028 Bonds". Since it is mentioned in these terms, I answered "Yes".',
#        'Based on the provided excerpt, my answers are:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "Yes"\n}\n\nHere\'s why:\n\n* a. Exposure to cyclical products: There is no mention of cyclical products in the excerpt.\n* b. Impact of demographic and structural trends: While not explicitly stated, industry volatility often relates to changes in demographics or market conditions. The text mentions the potential for material adverse effects on BCP\'s business due to uncertainties, which could imply broader market or economic factors that may be influenced by demographic and structural trends.\n* c. Seasonal industry volatility: This option is more closely related to cyclical products. However, the excerpt does not specifically mention seasonal fluctuations in the context of industries or specific products, but rather general business risks.',
#        'Here is the response in the requested JSON format:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "Yes"\n}',
#        'Based on the provided excerpt, here is the answer to each question in JSON format:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "No"\n}',
#        '{\n  "a": "Yes",\n  "b": "No",\n  "c": "No"\n}',
#        '{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}',
#        'Based on the provided excerpt, my answers are:\n\n{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}\n\nHere\'s why for each option:\n\na. Exposure to cyclical products: No\nThe text does not mention anything about SES being exposed to products that have a regular cycle of production and consumption, which is typically characteristic of cyclical industries.\n\nb. Impact of demographic and structural trends: No\nThere is no information in the excerpt regarding how demographic or structural changes might affect SES\'s business.\n\nc. Seasonal industry volatility: No\nThe text does not mention anything about seasonal fluctuations in SES\'s business or industry, which would be consistent with an expectation of seasonal volatility.',
#        'Based on the provided excerpt, here are the answers to the questions in JSON format:\n\n{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}\n\nThe text does not indicate exposure to cyclical products, impact of demographic and structural trends, or seasonal industry volatility. It focuses on risks associated with satellite launches, failures, and other operational issues, as well as potential exclusions from insurance coverage.',
#        '{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}',
#        '{\n  "a": "Yes",\n  "b": "No",\n  "c": "Yes"\n}',
#        '{\n  "a": "No",\n  "b": "Yes",\n  "c": "Yes"\n}',
#        'Based on the provided excerpt, here is the answer to each question in JSON format:\n\n{\n  "a": "Yes",\n  "b": "Yes",\n  "c": "Yes"\n}\n\nExplanation for each answer:\n\n* a. Exposure to cyclical products: Yes\nThe text mentions that some material satellite capacity contracts have long-term terms (e.g., several years) and that the Group may face challenges in winning back or replacing customers who decide not to renew their agreements. This suggests exposure to cyclical products, where demand is periodic and subject to fluctuations.\n* b. Impact of demographic and structural trends: Yes\nThe text mentions various factors that could impact the Group\'s business, such as consolidation in industries, development of relationships with other operators, and changes in customer behavior (e.g., moving to other telecommunications solutions). These factors suggest exposure to the impacts of demographic and structural trends.\n* c. Seasonal industry volatility: No\nThere is no indication in the text that the industry or products are subject to seasonal fluctuations or variability.',
#        'Based on the provided excerpt, here is the response in the requested JSON format:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "Yes"\n}\n\nThe reason for these answers is as follows:\n\n* a. Exposure to cyclical products: The text does not mention anything about exposure to cyclical products, so the answer is "No".\n* b. Impact of demographic and structural trends: While the excerpt mentions growing revenue in developing markets, it does not specifically address how these markets\' demographics or structures might impact product sales or revenue cycles.\n* c. Seasonal industry volatility: The text does not mention anything about seasonal fluctuations or industry volatility, so the answer is "No".',
#        'Based on the provided excerpt, here is the determination of whether each option indicates a risk of exposure to cyclical products:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "Yes"\n}\n\nHere\'s why:\n\na. Exposure to cyclical products: The text does not explicitly mention cyclical products or their impact on SES\'s operations.\n\nb. Impact of demographic and structural trends: There is no mention of demographic or structural changes affecting the satellite industry in general, so this option can be considered as "No".\n\nc. Seasonal industry volatility: Natural disasters are mentioned as a risk that could cause disruption to SES\'s operations, which can be seasonal in nature (e.g., hurricanes). This indicates a risk related to cyclical products ("Yes").',
#        'Based on the provided excerpt, I would respond as follows:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "No"\n}\n\nExplanation:\n\n* a. Exposure to cyclical products: No, there is no indication in the text that the Group\'s business is exposed to cyclical products.\n* b. Impact of demographic and structural trends: Yes, while not explicitly stated, the mention of technological advancements, changes in cybersecurity threats, and shifts in regulatory requirements suggest that the Group operates in an industry influenced by demographic and structural trends.\n* c. Seasonal industry volatility: No, there is no indication in the text that the Group\'s business is subject to seasonal fluctuations or industry-wide volatility.',
#        'Based on the provided excerpt, here is the answer in JSON format:\n\n{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}',
#        'Given the excerpt, I would determine as follows:\n\n{\n  "a": "Yes",\n  "b": "Yes",\n  "c": "Yes"\n}\n\nExplanation:\n\n* a. Exposure to cyclical products: Yes, because the text mentions that the Group\'s business is impacted by the global economy and demand for its products and services may be reduced due to COVID-19, suggesting exposure to cyclical products.\n* b. Impact of demographic and structural trends: Yes, although the text does not explicitly mention demographic or structural trends, it does mention a restructuring/consolidation process in some parts of the sectors the Group serves, which could be related to such trends.\n* c. Seasonal industry volatility: Yes, because the text mentions the possibility of reduced operators due to symptoms similar to COVID-19, implying seasonal industry volatility.\n\nNote that these classifications are based on a general understanding of common business risks and may not be specific or precise enough for a formal analysis.',
#        'Based on the provided excerpt, I would answer as follows:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "No"\n}\n\nExplanation:\n\n* a. The text does not mention exposure to cyclical products.\n* b. The text mentions "demographic and structural trends" in developing markets, which implies an impact from demographic and structural changes.\n* c. There is no mention of seasonal industry volatility.',
#        'Based on the provided excerpt, I would answer as follows:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "No"\n}\n\nThe excerpt does not explicitly mention cyclical products, but it does discuss a potential risk of higher costs due to increased competition and commoditisation of traditional satellite capacity sales. This could be related to exposure to cyclical products if the company\'s value-add services are subject to fluctuations in demand that follow an economic cycle.\n\nOn the other hand, demographic and structural trends (b) are mentioned as part of the group\'s development strategy to counter competition and commoditisation of traditional satellite capacity sales. This suggests that the company is aware of and adapting to changes in its market environment due to shifts in demographics and consumer behavior.\n\nSeasonal industry volatility (c) is not explicitly mentioned, but it could be inferred from the mention of cyclical products if those products are subject to seasonal fluctuations in demand. However, without explicit mention, I did not include this answer as "Yes".',
#        'Based on the provided excerpt, my answers are:\n\n{\n  "a": "Yes",\n  "b": "No",\n  "c": "No"\n}\n\nThe excerpt mentions a risk of exposure to cyclical products (a) due to assumptions such as no deterioration in market conditions within the satellite industry, including customer demand or competitive environment.\n\nIt does not explicitly mention demographic and structural trends (b), which are common risks associated with cyclical industries. \n\nThere is also no mention of seasonal industry volatility (c).',
#        '{\n  "a": "No",\n  "b": "Yes",\n  "c": "No"\n}',
#        'Given the excerpt, I would conclude that there is no indication of exposure to cyclical products. Here\'s why:\n\n{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}\n\nThe excerpt does not mention anything related to cyclical products, seasonal industry volatility, or demographic and structural trends. It primarily focuses on the challenges and risks associated with pursuing external growth opportunities through strategic acquisitions or investments.',
#        '{\n  "a": "Yes",\n  "b": "Yes",\n  "c": "No"\n}',
#        '{\n  "a": "Yes",\n  "b": "Yes",\n  "c": "No"\n}',
#        'Based on the provided excerpt, here is the response in the requested JSON format:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "No"\n}\n\nHere\'s the reasoning for each answer:\n\na. Exposure to cyclical products: No, there is no indication that SES is subject to risks from exposure to cyclical products.\n\nb. Impact of demographic and structural trends: Yes, the excerpt mentions "disputes in relation to SES’s business" which could be influenced by demographic or structural changes.\n\nc. Seasonal industry volatility: No, the excerpt does not mention anything related to seasonal industry volatility.',
#        '{\n  "a": "No",\n  "b": "Yes",\n  "c": "Yes"\n}',
#        '{\n  "a": "No",\n  "b": "Yes",\n  "c": "Yes"\n}',
#        'Based on the provided excerpt, here is the JSON response:\n\n{\n  "a": "Yes",\n  "b": "No",\n  "c": "No"\n}\n\nExplanation:\n\n- The text mentions that national administrations may charge for access to spectrum through fees and auctions (point 4). This suggests a cyclical nature of demand for spectrum, as governments may introduce new regulations or increase fees during economic downturns.\n- There is no mention of demographic or structural trends impacting the Group\'s business, making option b "No".\n- The text does not indicate any seasonal industry volatility, so option c "No".',
#        'Given the excerpt, here\'s the analysis of each risk factor:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "Yes"\n}\n\nHere\'s why:\n\n- a. Exposure to cyclical products: The text does not indicate exposure to cyclical products. It discusses risks related to regulatory and operational issues with satellite operators, ITU regulations, and national laws, which do not appear to be cyclic in nature.\n\n- b. Impact of demographic and structural trends: There is no indication that the risks discussed are directly influenced by demographic or structural changes within a specific industry or market segment.\n\n- c. Seasonal industry volatility: The text mentions coordination issues with other satellite operators, ITU regulations, national laws, and potential litigation, which could lead to reputational harm, financial impacts, and operational restrictions. These types of risks can be subject to seasonal fluctuations in terms of regulatory scrutiny or enforcement actions during specific times of the year, such as when new regulations are implemented or during changes in government policies.',
#        '{\n  "a": "No",\n  "b": "Yes",\n  "c": "No"\n}',
#        'Based on the provided excerpt, here is the response in the requested JSON format:\n\n{\n  "a": "Yes",\n  "b": "No",\n  "c": "No"\n}\n\nExplanation:\n\n* a. Exposure to cyclical products: Yes, as the text mentions that export control laws and regulations may impede construction and delay the launch of future satellites, which could negatively impact revenue.\n* b. Impact of demographic and structural trends: No, there is no mention of demographics or structural changes affecting the company\'s business in the provided excerpt.\n* c. Seasonal industry volatility: No, there is no indication that seasonal fluctuations are a concern for the company.',
#        '{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}',
#        'Based on the provided excerpt, my answers are:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "Yes"\n}\n\nExplanation:\n- a. The text does not explicitly mention cyclical products, so I answered "No".\n- b. The text mentions demographic and structural trends, which could impact the telecommunications industry, so I answered "Yes".\n- c. While the text doesn\'t directly say seasonal industry volatility, it implies that there are regulatory risks associated with being in a heavily regulated industry, which can sometimes lead to cyclical or seasonally volatile products. So I answered "Yes".',
#        'Based on the provided excerpt, I would answer as follows:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "No"\n}\n\nExplanation:\n\na. Exposure to cyclical products: No, there is no indication in the text that SES or SES Americas are involved with cyclical products.\n\nb. Impact of demographic and structural trends: Yes, the fact that SES\'s ability to meet its financial obligations is dependent on cash flows from domestic and foreign subsidiaries and affiliated companies suggests that the company may be exposed to changes in demographics and structural trends that could impact their operations.\n\nc. Seasonal industry volatility: No, there is no indication in the text that SES or SES Americas operate in an industry subject to seasonal fluctuations.',
#        'Based on the provided excerpt, my answers are:\n\n{\n  "a": "Yes",\n  "b": "Yes",\n  "c": "Yes"\n}\n\nExplanation:\n- a. Exposure to cyclical products: Yes. The text implies that SES\'s satellite fleet business may be vulnerable to economic downturns or changes in capital availability, which can lead to reduced operations and debt servicing difficulties.\n- b. Impact of demographic and structural trends: Yes. Although not explicitly stated, it is possible that the development and operation of satellites are influenced by broader societal factors such as population growth, technological advancements, and increasing demand for data services.\n- c. Seasonal industry volatility: Yes. The text mentions potential "material adverse effects" on SES\'s business resulting from various scenarios, including reduced operations or asset sales, which could be related to seasonal fluctuations in the satellite industry, especially during periods of low demand or reduced investment.',
#        'Based on the provided excerpt, here is the response in the requested JSON format:\n\n{\n  "a": "Yes",\n  "b": "No",\n  "c": "No"\n}',
#        'Since there is no mention of cyclical products, seasonal industry volatility, or demographic and structural trends in the provided excerpt, the correct answer would be:\n\n{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}',
#        '{\n  "a": "Yes",\n  "b": "Yes",\n  "c": "No"\n}',
#        'Given the excerpt, I would determine that there is no indication of exposure to cyclical products. The text only discusses asset impairment risk and valuation procedures for non-current intangible and tangible assets.\n\nHere\'s the answer in JSON format:\n\n{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}',
#        'Based on the text, my answers are:\n\n{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}\n\nThe text does not mention cyclical products, demographic and structural trends, or seasonal industry volatility. It specifically mentions the risk of investing in perpetual securities with no fixed redemption date.',
#        'Given the excerpt, I would answer as follows:\n\n{\n  "a": "Yes",\n  "b": "No",\n  "c": "Yes"\n}\n\nHere\'s why:\n\n* a. Exposure to cyclical products: Yes\nThe text mentions that during any period when the Issuer may, or may be perceived to be able to, elect to redeem the Securities, the market value of the Securities generally will not rise substantially above the price at which they can be redeemed. This suggests that investors may be exposed to a risk that the securities\' value may drop significantly if the Issuer chooses to redeem them.\n* b. Impact of demographic and structural trends: No\nThere is no mention of demographic or structural trends in the excerpt, which are often factors associated with cyclical products.\n* c. Seasonal industry volatility: Yes\nWhile not explicitly stated, the fact that there is a Call Date mentioned (e.g., "on any Call Date thereafter") and an event-driven redemption clause suggests that the product may be subject to market fluctuations or other external factors that could lead to seasonal industry volatility.',
#        '{\n  "a": "Yes",\n  "b": "No",\n  "c": "No"\n}',
#        'Based on the text, here is the assessment of the risks mentioned:\n\n{\n  "a": "Yes",\n  "b": "Yes",\n  "c": "No"\n}\n\nHere\'s why:\n\n* a. Exposure to cyclical products: Yes\nThe text mentions exposure to the reset of interest rates linked to the 5 year Swap Rate, which is an indicator of cyclical products. The variability of the 5 year Swap Rate and its potential impact on the Securities\' value suggests exposure to cyclical products.\n* b. Impact of demographic and structural trends: No\nThe text does not mention any demographic or structural trends that may affect the Securities.\n* c. Seasonal industry volatility: No\nThere is no indication in the text of seasonal industry volatility, which typically refers to fluctuations in an industry\'s performance over time due to changes in consumer behavior, government policies, etc. The only mentioned risk is related to market interest rates and their impact on the Securities\' value.',
#        '{\n  "a": "Yes",\n  "b": "Yes",\n  "c": "No"\n}',
#        'Based on the provided excerpt, I would answer as follows:\n\n{\n  "a": "Yes",\n  "b": "No",\n  "c": "No"\n}\n\nThe text mentions that "any deferral of interest payments or any perceived increase in the likelihood thereof is likely to have an adverse effect on the market price of the Securities", which suggests exposure to cyclical products. There is no mention of demographic and structural trends, nor seasonal industry volatility.',
#        '{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}',
#        'Based on the provided text, my answers are as follows:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "Yes"\n}\n\nHere\'s why for each answer:\n\na. Exposure to cyclical products: No\nThe text does not explicitly mention exposure to cyclical products. While it mentions the risk of the Issuer becoming insolvent, which could be a result of various factors including economic downturns or industry fluctuations, it does not specifically indicate that the securities are tied to cyclically related products.\n\nb. Impact of demographic and structural trends: Yes\nThe text mentions that the holders of Securities may recover less than other subordinated liabilities due to lower ranking claims, which could be affected by changes in market conditions, regulatory requirements, or industry shifts brought about by demographic and structural trends.\n\nc. Seasonal industry volatility: Yes\nWhile not explicitly stated, seasonal industry volatility is a plausible scenario given that the text mentions the risk of insolvency and default under various circumstances, including notice from an administrator or receiver declaring and distributing dividends. The mention of such events can be associated with cyclically volatile industries where profits may fluctuate seasonally.',
#        'Given the excerpt, I would determine as follows:\n\n{\n  "a": "Yes",\n  "b": "No",\n  "c": "No"\n}\n\nExplanation for a: The mention of "restructuring", "amalgamation", and "reorganisation" in paragraph (ii) of the Guarantee terms suggests that the Issuer or Guarantor may be involved with cyclical products, which are typically subject to fluctuations in demand due to changes in economic conditions. This exposure could potentially lead to losses for Holders if they sell the Securities.\n\nExplanation for b: There is no mention of demographic and structural trends in the excerpt. \n\nExplanation for c: There is no mention of seasonal industry volatility in the excerpt.',
#        '{\n  "a": "Yes",\n  "b": "No",\n  "c": "No"\n}',
#        '{\n  "a": "Yes",\n  "b": "No",\n  "c": "No"\n}',
#        '{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}',
#        '{\n  "a": "Yes",\n  "b": "Yes",\n  "c": "Yes"\n}',
#        'Based on the provided excerpt, I would determine the following:\n\n{\n  "a": "Yes",\n  "b": "Yes",\n  "c": "Yes"\n}\n\nThe reasons for each answer are as follows:\n\na. Exposure to cyclical products: Yes\nThe text mentions that substitution of the Securities could have a significant adverse impact on the price of, and/or market for, the Securities. This implies exposure to cyclical products due to changes in demand or supply.\n\nb. Impact of demographic and structural trends: Yes\nAlthough not explicitly stated, the mention of "individual Holders" suggests that the prospectus is focused on individual investors rather than institutional investors. Demographic and structural trends may affect how individual investors hold and market their securities, potentially impacting the market for the Securities.\n\nc. Seasonal industry volatility: Yes\nThe text does not specifically mention seasonal fluctuations, but it implies that changes to the terms of the Securities could occur due to Accounting Events, Capital Events, Tax Deduction Events, or Withholding Tax Events. These events can be influenced by seasonal patterns in various industries.',
#        'Based on the excerpt, I would answer as follows:\n\n{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}\n\nThe text does not mention cyclical products, demographic and structural trends, or seasonal industry volatility. It only discusses changes in law and its potential impact on the securities.',
#        'Based on the provided excerpt, here are my answers in JSON format:\n\n{\n  "a": "Yes",\n  "b": "Yes",\n  "c": "Yes"\n}\n\nHere\'s why for each option:\n\na. Exposure to cyclical products: Yes\nThe Global Certificate is held by or on behalf of Euroclear and Clearstream, Luxembourg, which suggests that the holder will be exposed to cyclical products as the certificates are maintained in a nominee name.\n\nb. Impact of demographic and structural trends: Yes\nThe excerpt mentions that investors will have to rely on their own procedures for transfer, payment, and communication with the Issuer, indicating that there may be an impact from demographic or structural trends that affect how these procedures are handled.\n\nc. Seasonal industry volatility: Yes\nThe text mentions that Securities are represented by the Global Certificate, but payments under such Securities will be made to (or for the order of) the Relevant Nominee for distribution to their account holders. This could lead to seasonal industry volatility as the payment schedule may not align with typical market conditions, exposing investors to potential risks related to the timing of payments.',
#        'Given the excerpt, I would determine that there is no indication of exposure to cyclical products, seasonal industry volatility, or demographic and structural trends. However, the text does mention "market, additional factors and other factors that may affect the value of the Securities", which implies some level of market risk.\n\nSo, my answers are:\n\n{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}',
#        '{\n  "a": "Yes",\n  "b": "No",\n  "c": "No"\n}',
#        "Based on the text, I would determine that:\n\n* a. Exposure to cyclical products: No\nThe text does not mention exposure to cyclical products. It discusses risks related to liquidity and market volatility in the secondary market.\n* b. Impact of demographic and structural trends: No\nThere is no mention of demographic or structural trends affecting the bond's performance or market value.\n* c. Seasonal industry volatility: No\nThe text does not discuss seasonal fluctuations in industries as a risk factor for the bonds.",
#        'Given the excerpt, I would respond as follows:\n\n{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}\n\nThe text does not indicate exposure to cyclical products (a), impact of demographic and structural trends (b), or seasonal industry volatility (c). It primarily discusses currency exchange rate risks, exchange controls, and the potential impact on investor returns due to fluctuations in exchange rates.',
#        'Based on the provided excerpt, here is the answer in the requested JSON format:\n\n{\n  "a": "No",\n  "b": "No",\n  "c": "No"\n}\n\nThe text does not indicate exposure to cyclical products (a), demographic and structural trends (b), or seasonal industry volatility (c). The mention of legal considerations and regulatory implications is related to compliance with laws and regulations, but it does not specifically relate to the nature of the investment products themselves.',
#        'Based on the excerpt, I would conclude that:\n\n- a. Exposure to cyclical products: Yes\nThe mention of fluctuations in interest rates suggests that the securities are sensitive to changes in market conditions, which is characteristic of cyclical products.\n\n- b. Impact of demographic and structural trends: No\nThere is no indication in the excerpt that the value of the Securities would be affected by demographic or structural trends.\n\n- c. Seasonal industry volatility: No\nThe excerpt does not mention anything about seasonal fluctuations or industry volatility, which suggests that this risk is not applicable to the securities mentioned.',
#        '{\n  "a": "Yes",\n  "b": "No",\n  "c": "No"\n}',
#        'Based on the provided excerpt, my answers are:\n\n{\n  "a": "No",\n  "b": "Yes",\n  "c": "Yes"\n}\n\nHere\'s why:\n\n* a. Exposure to cyclical products: There is no mention of cyclical products in the excerpt, so the answer is "No".\n* b. Impact of demographic and structural trends: The excerpt mentions factors that could have a material adverse effect on the Group\'s business, financial condition, results of operations, and future prospects, which implies that demographic and structural changes may be a risk. Therefore, the answer is "Yes".\n* c. Seasonal industry volatility: Although not explicitly stated, the mention of factors such as seasonality (e.g., "the Issuer and the Guarantor believe that the following factors may affect their ability to fulfil their obligations under the Securities") suggests that seasonal industry volatility could be a risk. Therefore, the answer is "Yes".'],
#       dtype=object)
