# %%
from langchain_ollama import OllamaLLM
from tqdm import tqdm

import json
import numpy as np
import os
import pandas as pd
import re

# %%
rms_with_fundamental_score = pd.read_pickle('./rms_with_fundamental_score.pkl')
# Get values from 5 first rows of TaggedCharacteristics column
rms_with_fundamental_score['TaggedCharacteristics'].head(7).values
# Out:
# array(['[{"CharacteristicText":"Positive demographic, consumer & structural trends","CharacteristicInfluence":"Positive"}]',
#        '[{"CharacteristicText":"Market share is consolidated with top 3-5 players & limited fragmentation of remainder","CharacteristicInfluence":"Positive"}]',
#        '[{"CharacteristicText":"Company is viewed as a disruptor\\/benficiary from technological change","CharacteristicInfluence":"Positive"},{"CharacteristicText":"Industry is susceptible to technological advances","CharacteristicInfluence":"Negative"}]',
#        '[{"CharacteristicText":"Low dependecy on regulation or is a beneficiary from regulation in a stable regulatory evironment","CharacteristicInfluence":"Positive"},{"CharacteristicText":"Industry has high degree of regulatory scrutiny","CharacteristicInfluence":"Negative"}]',
# ...

# %%
rms_with_fundamental_score.head(7)
# Out:
#    RmsId ScoringDate     CategoryGroup                    Category  \
# 0    194  2021-04-15          Industry             Market Dynamics
# 1    194  2021-04-15          Industry  Intra-Industry Competition
# 2    194  2021-04-15  Industry/Company             Technology Risk
# 3    194  2021-04-15  Industry/Company        Regulatory Framework
# 4    194  2021-04-15           Company              Business Model
# 5    194  2021-04-15           Company      Management & Ownership
# 6    194  2021-04-15           Company     Competitive Positioning
#
#           Score                              TaggedCharacteristics  \
# 0  2.0000000000  [{"CharacteristicText":"Positive demographic, ...
# 1  2.0000000000  [{"CharacteristicText":"Market share is consol...
# 2  3.0000000000  [{"CharacteristicText":"Company is viewed as a...
# 3  3.0000000000  [{"CharacteristicText":"Low dependecy on regul...
# 4  2.0000000000  [{"CharacteristicText":"Well diversified (prod...
# ...
