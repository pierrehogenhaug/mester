# %%
import os
import time
import shutil
from collections import defaultdict
from pathlib import Path
import pandas as pd
import pickle
from selenium import webdriver
from selenium.webdriver.common.by import By

# Initialize paths
DATA_DIR = Path("../data")
RAW_DIR = DATA_DIR / "raw"
PROCESSED_DIR = DATA_DIR / "processed"
RMS_FUNDAMENTAL_SCORE_FILE = DATA_DIR / "rms_with_fundamental_score.csv"
RMS_ISIN_LINK_FILE = DATA_DIR / "isin_rms_link.csv"

# Read the grouped_isin list from pickle file
with open(DATA_DIR / "grouped_isins.pkl", "rb") as f:
    grouped_isin = pickle.load(f)

# %%
grouped_isin_small = grouped_isin[:5]

# %%
# Initialize download directory
download_dir = os.path.abspath("./temp_download")
if not os.path.exists(download_dir):
    os.makedirs(download_dir)

# %%
# Set up Selenium WebDriver with download preferences
chrome_options = webdriver.ChromeOptions()
preferences = {
    "download.default_directory": download_dir,
    "directory_upgrade": True,
    "safebrowsing.enabled": True
}
chrome_options.add_experimental_option("prefs", preferences)
browser = webdriver.Chrome(options=chrome_options)

def get_prospectus(browser, isin, output_folder):
    # Clear download directory before starting
    for f in os.listdir(download_dir):
        try:
            os.remove(os.path.join(download_dir, f))
        except Exception as e:
            print(f"Could not delete file {f} in download_dir: {e}")

    url = 'https://registers.esma.europa.eu/publication/searchRegister?core=esma_registers_priii_securities'
    browser.get(url)
    
    time.sleep(1)
    # Find ISIN field
    input_isin = browser.find_element(By.XPATH,'//*[@id="searchFields"]/div[1]/div/input')
    
    # Send ISIN
    input_isin.clear()
    input_isin.send_keys(isin)
    
    time.sleep(2)
    # Search
    search_button = browser.find_element(By.XPATH,'//*[@id="searchSolrButton"]')
    search_button.click()
    
    # Sleep to accommodate loading
    time.sleep(5)
    
    # Check if results are found
    try:
        prosp_button = browser.find_element(By.XPATH,'//*[@id="T01"]/tbody/tr/td[11]/a')
        prosp_button.click()
    except:
        print(f"No results found for ISIN {isin}")
        return False
    
    # Sleep to accommodate loading
    time.sleep(5)
    
    # Expand sections
    for val in range(7):
        try:
            time.sleep(1)
            exp_button = browser.find_element(By.XPATH, f'//*[@id="ui-id-{val}"]')
            exp_button.click()
        except:
            pass
    
    time.sleep(5)
    # Click document
    try:
        doc_button = browser.find_element(By.XPATH, '//*[@id="prospectuses"]/tbody/tr/td[2]/a')
        new_url = doc_button.get_attribute('href')
    except:
        print('Trying other approach')
        try:
            doc_button = browser.find_element(By.XPATH, '//*[@id="related_docs"]/tbody/tr/td[2]/a')
            new_url = doc_button.get_attribute('href')
        except:
            print(f"No documents found for ISIN {isin}")
            return False
    
    print(f"Navigating to document URL: {new_url}")
    browser.get(new_url)
    time.sleep(5)
    for val in range(10):
        try:
            time.sleep(1)
            browser.find_element(By.XPATH, f'//*[@id="detailsParent"]/tbody/tr[{val}]/td[2]/a').click()
        except:
            pass
    
    # Wait for download to finish
    time.sleep(20)
    
    # Attempt to find the downloaded file
    try:
        files = [os.path.join(download_dir, f) for f in os.listdir(download_dir)]
        if len(files) == 0:
            print(f"No files were downloaded for ISIN {isin}")
            return False
        elif len(files) > 1:
            print(f"Multiple files downloaded for ISIN {isin}, cannot determine correct file")
            return False
        else:
            filename = files[0]
            dest_path = os.path.join(output_folder, isin + '.pdf')
            if os.path.exists(dest_path):
                print(f"File {dest_path} already exists, not overwriting.")
                # Optionally, delete the downloaded file in download_dir
                os.remove(filename)
                return True
            else:
                shutil.move(filename, dest_path)
                time.sleep(1)
                return True
    except Exception as e:
        print(f"Failed to move downloaded file for ISIN {isin}: {e}")
        return False

# %%
# Load processed RmsIds
processed_rmsids_file = 'processed_rmsids.txt'
if os.path.exists(processed_rmsids_file):
    with open(processed_rmsids_file, 'r') as f:
        processed_rmsids = set(line.strip() for line in f)
else:
    processed_rmsids = set()
    
# Main processing loop
try:
    for rms_entry in grouped_isin:
        rms_id = rms_entry[0]
        
        # Skip if RmsId has already been processed
        if str(rms_id) in processed_rmsids:
            print(f"RmsId {rms_id} has already been processed. Skipping.")
            continue
        
        scoring_date_lists = rms_entry[1]
        
        # Define the output folder for this RmsId
        processed_folder = PROCESSED_DIR / str(rms_id) / "as_expected"
        output_folder = RAW_DIR / str(rms_id)
        
        if output_folder.exists():
            if processed_folder.exists():
                print(f"Prospectus for RmsId {rms_id} already exists at {processed_folder}, skipping.")
                continue
            else:
                print(f"Output folder for RmsId {rms_id} exists, proceeding without deleting existing files.")
        else:
            output_folder.mkdir(parents=True, exist_ok=True)
        
        for scoring_date_entry in scoring_date_lists:
            scoring_date = scoring_date_entry[0]
            isins_list = scoring_date_entry[1]
            
            is_success = False
            
            for isin in isins_list:
                # Define the expected file path for this ISIN
                file_path = output_folder / f"{isin}.pdf"
                if processed_folder.exists():
                    print(f"Prospectus for RmsId {rms_id} already exists at {processed_folder}")
                    is_success = True
                    break  # Move to next ScoringDate
                else:
                    # Try to get prospectus for this ISIN
                    try:
                        success = get_prospectus(browser, isin, output_folder)
                        if success:
                            print(f"Downloaded prospectus for ISIN {isin} to {file_path}")
                            is_success = True
                            break  # Move to next ScoringDate
                        # else:
                        #     print(f"Failed to download prospectus for ISIN {isin}")
                    except Exception as e:
                        print(f"Exception occurred while downloading ISIN {isin}: {e}")
                        # Continue to next ISIN
            if not is_success:
                print(f"Could not obtain prospectus for RmsId {rms_id}, ScoringDate {scoring_date}")
                # Optionally, log this information somewhere
        
        # After processing all ScoringDates for this RmsId, mark it as processed
        with open(processed_rmsids_file, 'a') as f:
            f.write(f"{rms_id}\n")
        processed_rmsids.add(str(rms_id))
        print(f"Finished processing RmsId {rms_id}.")
except Exception as e:
    print(f"An error occurred: {e}")
finally:
    # Close the browser after processing
    browser.quit()
# Out:
# Prospectus for RmsId 5 already exists at ../data/processed/5/as_expected
# Prospectus for RmsId 5 already exists at ../data/processed/5/as_expected
# Prospectus for RmsId 5 already exists at ../data/processed/5/as_expected
# Finished processing RmsId 5.
# Prospectus for RmsId 13 already exists at ../data/processed/13/as_expected
# Finished processing RmsId 13.
# Prospectus for RmsId 16 already exists at ../data/processed/16/as_expected, skipping.
# No results found for ISIN XS1134780557
# No results found for ISIN CH0253592783
# No results found for ISIN CH0200044813
# Could not obtain prospectus for RmsId 24, ScoringDate 2022-06-24 00:00:00
# Finished processing RmsId 24.
# Prospectus for RmsId 31 already exists at ../data/processed/31/as_expected, skipping.
# Output folder for RmsId 34 exists, proceeding without deleting existing files.
# No results found for ISIN XS2294186965
# No results found for ISIN XS2294187690
# No results found for ISIN BIOGRPEURSSNTAP
# Could not obtain prospectus for RmsId 34, ScoringDate 2022-03-24 00:00:00
# No results found for ISIN XS2294186965
# No results found for ISIN XS2294187690
# No results found for ISIN BIOGRPEURSSNTAP
# Could not obtain prospectus for RmsId 34, ScoringDate 2024-10-20 00:00:00
# Finished processing RmsId 34.
# Prospectus for RmsId 36 already exists at ../data/processed/36/as_expected, skipping.
# Prospectus for RmsId 43 already exists at ../data/processed/43/as_expected, skipping.
# Prospectus for RmsId 44 already exists at ../data/processed/44/as_expected, skipping.
# Output folder for RmsId 46 exists, proceeding without deleting existing files.
# No results found for ISIN XS2343001991
# No results found for ISIN XS2343000241
# No results found for ISIN XS2401605527
# No results found for ISIN XS2401605287
# No results found for ISIN XS1063354275
# No results found for ISIN XS0877607076
# Could not obtain prospectus for RmsId 46, ScoringDate 2021-05-11 00:00:00
# No results found for ISIN XS2401605527
# No results found for ISIN XS2401605287
# No results found for ISIN XS2343001991
# No results found for ISIN XS2343000241
# No results found for ISIN XS1063354275
# No results found for ISIN XS0877607076
# Could not obtain prospectus for RmsId 46, ScoringDate 2024-08-14 00:00:00
# Finished processing RmsId 46.
# Prospectus for RmsId 57 already exists at ../data/processed/57/as_expected, skipping.
# Output folder for RmsId 66 exists, proceeding without deleting existing files.
# No results found for ISIN XS2411541738
# No results found for ISIN XS2199627030
# No results found for ISIN XS2721513260
# No results found for ISIN XS1557228357
# Could not obtain prospectus for RmsId 66, ScoringDate 2021-12-22 00:00:00
# Finished processing RmsId 66.
# Output folder for RmsId 71 exists, proceeding without deleting existing files.
# No results found for ISIN XS0253493349
# No results found for ISIN XS0253496441
# No results found for ISIN XS0253496870
# No results found for ISIN XS0270064263
# Could not obtain prospectus for RmsId 71, ScoringDate 2022-06-28 00:00:00
# Finished processing RmsId 71.
# Output folder for RmsId 74 exists, proceeding without deleting existing files.
# No results found for ISIN XS2247614063
# No results found for ISIN XS2808453455
# No results found for ISIN USG28296AF17
# No results found for ISIN US26151AAA79
# No results found for ISIN XS1602280676
# No results found for ISIN XS1602281567
# Could not obtain prospectus for RmsId 74, ScoringDate 2022-02-21 00:00:00
# Finished processing RmsId 74.
# Output folder for RmsId 75 exists, proceeding without deleting existing files.
# No results found for ISIN XS2380124227
# Could not obtain prospectus for RmsId 75, ScoringDate 2021-09-03 00:00:00
# Finished processing RmsId 75.
# Prospectus for RmsId 79 already exists at ../data/processed/79/as_expected, skipping.
# Output folder for RmsId 80 exists, proceeding without deleting existing files.
# No results found for ISIN CGDF_2L
# Could not obtain prospectus for RmsId 80, ScoringDate 2024-04-19 00:00:00
# Finished processing RmsId 80.
# Output folder for RmsId 84 exists, proceeding without deleting existing files.
# No results found for ISIN XS1778521986
# No results found for ISIN XS1607258859
# No results found for ISIN XS1499772280
# No results found for ISIN XS1272329621
# Could not obtain prospectus for RmsId 84, ScoringDate 2022-03-09 00:00:00
# No results found for ISIN XS1778521986
# No results found for ISIN XS1607258859
# No results found for ISIN XS1499772280
# No results found for ISIN XS1272329621
# Could not obtain prospectus for RmsId 84, ScoringDate 2022-03-25 00:00:00
# No results found for ISIN XS1778521986
# No results found for ISIN XS1607258859
# No results found for ISIN XS1499772280
# No results found for ISIN XS1272329621
# Could not obtain prospectus for RmsId 84, ScoringDate 2023-05-25 00:00:00
# Finished processing RmsId 84.
# Output folder for RmsId 88 exists, proceeding without deleting existing files.
# No results found for ISIN XS2338545655
# Could not obtain prospectus for RmsId 88, ScoringDate 2021-04-22 00:00:00
# Finished processing RmsId 88.
# Output folder for RmsId 95 exists, proceeding without deleting existing files.
# No results found for ISIN XS2353416386
# No results found for ISIN XS1846665534
# Could not obtain prospectus for RmsId 95, ScoringDate 2022-02-22 00:00:00
# No results found for ISIN XS2353416386
# No results found for ISIN XS1846665534
# Could not obtain prospectus for RmsId 95, ScoringDate 2023-09-12 00:00:00
# Finished processing RmsId 95.
# Prospectus for RmsId 107 already exists at ../data/processed/107/as_expected, skipping.
# Output folder for RmsId 119 exists, proceeding without deleting existing files.
# No results found for ISIN XS2326497802
# No results found for ISIN XS2326505240
# No results found for ISIN XS1251078777
# No results found for ISIN XS1251078694
# No results found for ISIN XS1251078009
# No results found for ISIN XS0289201484_2
# No results found for ISIN USF6628RAA17_2
# No results found for ISIN XS1137506850_2
# No results found for ISIN dummy
# Could not obtain prospectus for RmsId 119, ScoringDate 2021-10-24 00:00:00
# No results found for ISIN XS2326497802
# No results found for ISIN XS2326505240
# No results found for ISIN XS1251078777
# No results found for ISIN XS1251078694
# No results found for ISIN XS1251078009
# No results found for ISIN XS0289201484_2
# No results found for ISIN USF6628RAA17_2
# No results found for ISIN XS1137506850_2
# No results found for ISIN dummy
# Could not obtain prospectus for RmsId 119, ScoringDate 2022-06-21 00:00:00
# Finished processing RmsId 119.
# Output folder for RmsId 120 exists, proceeding without deleting existing files.
# No results found for ISIN XS2166106448
# No results found for ISIN XS2106524262
# No results found for ISIN XS1802140894
# No results found for ISIN XS2828830153
# No results found for ISIN XS1551285007
# No results found for ISIN XS0235245205
# No results found for ISIN XS0133173137
# Could not obtain prospectus for RmsId 120, ScoringDate 2021-02-17 00:00:00
# Finished processing RmsId 120.
# Prospectus for RmsId 124 already exists at ../data/processed/124/as_expected, skipping.
# Prospectus for RmsId 127 already exists at ../data/processed/127/as_expected, skipping.
# Prospectus for RmsId 130 already exists at ../data/processed/130/as_expected, skipping.
# Prospectus for RmsId 131 already exists at ../data/processed/131/as_expected, skipping.
# Prospectus for RmsId 133 already exists at ../data/processed/133/as_expected, skipping.
# Output folder for RmsId 135 exists, proceeding without deleting existing files.
# No results found for ISIN XS2247623643
# No results found for ISIN XS1886399093
# Could not obtain prospectus for RmsId 135, ScoringDate 2021-10-29 00:00:00
# Finished processing RmsId 135.
# Prospectus for RmsId 136 already exists at ../data/processed/136/as_expected, skipping.
# Prospectus for RmsId 137 already exists at ../data/processed/137/as_expected, skipping.
# Prospectus for RmsId 139 already exists at ../data/processed/139/as_expected, skipping.
# Output folder for RmsId 143 exists, proceeding without deleting existing files.
# No results found for ISIN XS2275090749
# No results found for ISIN XS2275101967
# No results found for ISIN XS2805530693
# Could not obtain prospectus for RmsId 143, ScoringDate 2022-10-19 00:00:00
# Finished processing RmsId 143.
# Output folder for RmsId 148 exists, proceeding without deleting existing files.
# No results found for ISIN XS2344474320
# No results found for ISIN XS2719293826
# No results found for ISIN XS1908248963
# No results found for ISIN XS1908258681
# Could not obtain prospectus for RmsId 148, ScoringDate 2021-11-29 00:00:00
# Finished processing RmsId 148.
# Prospectus for RmsId 151 already exists at ../data/processed/151/as_expected, skipping.
# Prospectus for RmsId 155 already exists at ../data/processed/155/as_expected, skipping.
# Prospectus for RmsId 156 already exists at ../data/processed/156/as_expected, skipping.
# Prospectus for RmsId 162 already exists at ../data/processed/162/as_expected, skipping.
# Prospectus for RmsId 164 already exists at ../data/processed/164/as_expected, skipping.
# Output folder for RmsId 171 exists, proceeding without deleting existing files.
# No results found for ISIN DE000A2NB965
# Could not obtain prospectus for RmsId 171, ScoringDate 2022-02-22 00:00:00
# Finished processing RmsId 171.
# Prospectus for RmsId 172 already exists at ../data/processed/172/as_expected, skipping.
# Output folder for RmsId 174 exists, proceeding without deleting existing files.
# No results found for ISIN NO0010856966
# Could not obtain prospectus for RmsId 174, ScoringDate 2021-10-31 00:00:00
# Finished processing RmsId 174.
# Prospectus for RmsId 177 already exists at ../data/processed/177/as_expected, skipping.
# Output folder for RmsId 182 exists, proceeding without deleting existing files.
# No results found for ISIN XS0258796274
# Could not obtain prospectus for RmsId 182, ScoringDate 2021-04-07 00:00:00
# Finished processing RmsId 182.
# Prospectus for RmsId 187 already exists at ../data/processed/187/as_expected, skipping.
# Output folder for RmsId 194 exists, proceeding without deleting existing files.
# No results found for ISIN XS2332590475
# No results found for ISIN XS2332589972
# No results found for ISIN XS2066703989
# Could not obtain prospectus for RmsId 194, ScoringDate 2021-04-15 00:00:00
# No results found for ISIN XS2332590475
# No results found for ISIN XS2332589972
# No results found for ISIN XS2066703989
# Could not obtain prospectus for RmsId 194, ScoringDate 2022-09-27 00:00:00
# Finished processing RmsId 194.
# Prospectus for RmsId 199 already exists at ../data/processed/199/as_expected, skipping.
# Prospectus for RmsId 201 already exists at ../data/processed/201/as_expected, skipping.
# Prospectus for RmsId 207 already exists at ../data/processed/207/as_expected, skipping.
# Prospectus for RmsId 211 already exists at ../data/processed/211/as_expected, skipping.
# Prospectus for RmsId 213 already exists at ../data/processed/213/as_expected, skipping.
# Prospectus for RmsId 219 already exists at ../data/processed/219/as_expected, skipping.
# Prospectus for RmsId 221 already exists at ../data/processed/221/as_expected, skipping.
# Output folder for RmsId 224 exists, proceeding without deleting existing files.
# No results found for ISIN FI4000410667
# Could not obtain prospectus for RmsId 224, ScoringDate 2022-10-31 00:00:00
# Finished processing RmsId 224.
# Output folder for RmsId 225 exists, proceeding without deleting existing files.
# No results found for ISIN XS1028957469
# Could not obtain prospectus for RmsId 225, ScoringDate 2021-07-28 00:00:00
# Finished processing RmsId 225.
# Prospectus for RmsId 226 already exists at ../data/processed/226/as_expected, skipping.
# Prospectus for RmsId 235 already exists at ../data/processed/235/as_expected, skipping.
# Output folder for RmsId 238 exists, proceeding without deleting existing files.
# No results found for ISIN XS2646608401
# No results found for ISIN XS2582389156
# No results found for ISIN XS2462605671
# No results found for ISIN XS2755535577
# No results found for ISIN XS2901990429
# No results found for ISIN XS2410367747
# No results found for ISIN XS2293060658
# No results found for ISIN XS2109819859
# No results found for ISIN XS2056371334
# No results found for ISIN XS1933828433
# No results found for ISIN XS1795406658
# No results found for ISIN XS1795406575
# No results found for ISIN XS1731823255
# No results found for ISIN XS1490960942
# No results found for ISIN XS1148359356
# No results found for ISIN XS1050460739
# No results found for ISIN XS1050461034
# No results found for ISIN XS0997326441
# No results found for ISIN XS0972570351
# No results found for ISIN XS0972588643
# No results found for ISIN XS0410258833
# No results found for ISIN XS0241946630
# Could not obtain prospectus for RmsId 238, ScoringDate 2023-06-28 00:00:00
# Finished processing RmsId 238.
# Prospectus for RmsId 250 already exists at ../data/processed/250/as_expected, skipping.
# Prospectus for RmsId 251 already exists at ../data/processed/251/as_expected, skipping.
# Prospectus for RmsId 252 already exists at ../data/processed/252/as_expected, skipping.
# Prospectus for RmsId 253 already exists at ../data/processed/253/as_expected, skipping.
# Output folder for RmsId 257 exists, proceeding without deleting existing files.
# No results found for ISIN XS2359953283
# Could not obtain prospectus for RmsId 257, ScoringDate 2020-12-09 00:00:00
# Finished processing RmsId 257.
# Prospectus for RmsId 261 already exists at ../data/processed/261/as_expected, skipping.
# Output folder for RmsId 266 exists, proceeding without deleting existing files.
# No results found for ISIN XS2606019383
# No results found for ISIN DE000A3823S1
# No results found for ISIN DE000A3823R3
# No results found for ISIN DE000A383HC1
# No results found for ISIN XS2905386962
# No results found for ISIN XS2905387697
# No results found for ISIN US44963BAG32
# No results found for ISIN US44963BAF58
# No results found for ISIN DE000A3H2TA0
# No results found for ISIN DE000A289Q91
# No results found for ISIN US44963BAE83
# No results found for ISIN US44963BAD01
# No results found for ISIN XS2004438458
# No results found for ISIN XS2004451121
# No results found for ISIN DE000A2YB699
# No results found for ISIN DE000A2YB7A7
# No results found for ISIN DE000A2YB7B5
# No results found for ISIN XS1490153886
# No results found for ISIN XS1490159495
# No results found for ISIN XS1490152565
# No results found for ISIN US80627DAA46
# No results found for ISIN US80627DAB29
# No results found for ISIN US80627DAC02
# No results found for ISIN US806261AM57
# No results found for ISIN XS1212469966
# No results found for ISIN XS1212470972
# No results found for ISIN XS1126486239
# No results found for ISIN US80626PAC41
# No results found for ISIN US80626PAD24
# No results found for ISIN XS1067864881
# No results found for ISIN XS1067862919
# No results found for ISIN XS1067864022
# No results found for ISIN US806261AJ29
# No results found for ISIN XS0954907787
# No results found for ISIN US80626PAA84
# No results found for ISIN USN77608AD49
# No results found for ISIN US806261AE32
# No results found for ISIN XS0923613490
# No results found for ISIN XS0923613060
# No results found for ISIN XS0801261156
# No results found for ISIN XS0741939788
# No results found for ISIN XS0741938624
# Could not obtain prospectus for RmsId 266, ScoringDate 2022-12-01 00:00:00
# Finished processing RmsId 266.
# Prospectus for RmsId 267 already exists at ../data/processed/267/as_expected, skipping.
# Prospectus for RmsId 270 already exists at ../data/processed/270/as_expected, skipping.
# Prospectus for RmsId 281 already exists at ../data/processed/281/as_expected, skipping.
# Output folder for RmsId 282 exists, proceeding without deleting existing files.
# No results found for ISIN SE0015530712
# Could not obtain prospectus for RmsId 282, ScoringDate 2021-01-01 00:00:00
# Finished processing RmsId 282.
# Prospectus for RmsId 284 already exists at ../data/processed/284/as_expected, skipping.
# Prospectus for RmsId 287 already exists at ../data/processed/287/as_expected, skipping.
# Output folder for RmsId 291 exists, proceeding without deleting existing files.
# No results found for ISIN XS2199597456
# No results found for ISIN XS2199597613
# No results found for ISIN XS2198191962
# No results found for ISIN US92537VAA89
# Could not obtain prospectus for RmsId 291, ScoringDate 2022-10-10 00:00:00
# Finished processing RmsId 291.
# Prospectus for RmsId 297 already exists at ../data/processed/297/as_expected, skipping.
# Prospectus for RmsId 299 already exists at ../data/processed/299/as_expected, skipping.
# Prospectus for RmsId 303 already exists at ../data/processed/303/as_expected, skipping.
# Output folder for RmsId 313 exists, proceeding without deleting existing files.
# No results found for ISIN BE6342263157
# No results found for ISIN BE6355549120
# Could not obtain prospectus for RmsId 313, ScoringDate 2023-03-07 00:00:00
# Finished processing RmsId 313.
# Output folder for RmsId 319 exists, proceeding without deleting existing files.
# No results found for ISIN USF1067PAE63
# No results found for ISIN US05565A5R02
# No results found for ISIN FR001400I9F5
# No results found for ISIN FR001400H8D3
# No results found for ISIN USF1067PAF39
# No results found for ISIN US05602XDJ46
# No results found for ISIN FR001400F6O6
# No results found for ISIN FR001400F2H9
# No results found for ISIN FR001400E3H8
# No results found for ISIN US05565AS207
# No results found for ISIN FR001400CSG4
# No results found for ISIN FR001400BBL2
# No results found for ISIN US05565AM341
# No results found for ISIN US05602XJC39
# No results found for ISIN FR001400BDD5
# No results found for ISIN FR001400AKP6
# No results found for ISIN FR0014008FH1
# No results found for ISIN US05565AB286
# No results found for ISIN USF1067PAB25
# No results found for ISIN FR0014006NI7
# No results found for ISIN FR0014005OL1
# No results found for ISIN FR0014002X43
# No results found for ISIN FR0014002NR7
# No results found for ISIN US05565ASK06
# No results found for ISIN FR00140005J1
# No results found for ISIN FR0013532280
# No results found for ISIN US05565ALQ49
# No results found for ISIN USF1R15XL274
# No results found for ISIN FR0013484458
# No results found for ISIN FR0013465358
# No results found for ISIN FR0013444759
# No results found for ISIN FR0013434776
# No results found for ISIN FR0013433257
# No results found for ISIN USF1R15XK938
# No results found for ISIN US05565AHN63
# No results found for ISIN FR0013405537
# No results found for ISIN FR0013398070
# No results found for ISIN USF1R15XK854
# No results found for ISIN US05565AGF49
# No results found for ISIN XS1823532640
# No results found for ISIN XS1808338542
# No results found for ISIN XS1793252419
# No results found for ISIN XS1748456974
# No results found for ISIN US05565ADW09
# No results found for ISIN XS1637277572
# No results found for ISIN XS1614416193
# No results found for ISIN XS1547407830
# No results found for ISIN US05565ACA97
# No results found for ISIN XS1527753187
# No results found for ISIN XS1394103789
# No results found for ISIN US05565AAQ67
# No results found for ISIN XS1369250755
# No results found for ISIN XS1345331299
# No results found for ISIN US05565AAN37
# No results found for ISIN XS1247508903
# No results found for ISIN FR0012329845
# No results found for ISIN XS1068871448
# No results found for ISIN XS1023684522
# No results found for ISIN XS0895249620
# No results found for ISIN XS0847433561
# No results found for ISIN XS0635033631
# No results found for ISIN XS0606704558
# No results found for ISIN XS0405664813
# No results found for ISIN FR0010306787
# No results found for ISIN FR0010239319
# No results found for ISIN XS0160850227
# No results found for ISIN BE0117584202
# Could not obtain prospectus for RmsId 319, ScoringDate 2023-08-18 00:00:00
# Finished processing RmsId 319.
# Output folder for RmsId 331 exists, proceeding without deleting existing files.
# No results found for ISIN XS1064790899
# No results found for ISIN XS0924046682
# Could not obtain prospectus for RmsId 331, ScoringDate 2020-12-09 00:00:00
# No results found for ISIN XS1064790899
# No results found for ISIN XS0924046682
# Could not obtain prospectus for RmsId 331, ScoringDate 2024-07-11 00:00:00
# Finished processing RmsId 331.
# Output folder for RmsId 337 exists, proceeding without deleting existing files.
# No results found for ISIN XS2329602135
# Could not obtain prospectus for RmsId 337, ScoringDate 2021-04-08 00:00:00
# Finished processing RmsId 337.
# Output folder for RmsId 339 exists, proceeding without deleting existing files.
# No results found for ISIN XS2413672234
# No results found for ISIN XS2117435904
# Could not obtain prospectus for RmsId 339, ScoringDate 2022-11-30 00:00:00
# Finished processing RmsId 339.
# Output folder for RmsId 341 exists, proceeding without deleting existing files.
# No results found for ISIN US45674GAA22
# No results found for ISIN XS2291929573
# No results found for ISIN XS2291928849
# No results found for ISIN XS2108560306
# No results found for ISIN US45674GAB05
# No results found for ISIN XS2719090636
# No results found for ISIN XS2915461458
# No results found for ISIN XS1405784288
# No results found for ISIN XS0628089426
# No results found for ISIN XS0480857415
# No results found for ISIN XS0180620626
# Could not obtain prospectus for RmsId 341, ScoringDate 2021-10-29 00:00:00
# No results found for ISIN US45674GAA22
# No results found for ISIN XS2291929573
# No results found for ISIN XS2291928849
# No results found for ISIN XS2108560306
# No results found for ISIN US45674GAB05
# No results found for ISIN XS2719090636
# No results found for ISIN XS2915461458
# No results found for ISIN XS1405784288
# No results found for ISIN XS0628089426
# No results found for ISIN XS0480857415
# No results found for ISIN XS0180620626
# Could not obtain prospectus for RmsId 341, ScoringDate 2021-11-02 00:00:00
# No results found for ISIN US45674GAB05
# No results found for ISIN XS2719090636
# No results found for ISIN XS2915461458
# No results found for ISIN US45674GAA22
# No results found for ISIN XS2291929573
# No results found for ISIN XS2291928849
# No results found for ISIN XS2108560306
# No results found for ISIN XS1405784288
# No results found for ISIN XS0628089426
# No results found for ISIN XS0480857415
# No results found for ISIN XS0180620626
# Could not obtain prospectus for RmsId 341, ScoringDate 2023-03-16 00:00:00
# Finished processing RmsId 341.
# Prospectus for RmsId 350 already exists at ../data/processed/350/as_expected, skipping.
# Output folder for RmsId 355 exists, proceeding without deleting existing files.
# No results found for ISIN BE6329443962
# No results found for ISIN BE6272861657
# No results found for ISIN XS0611589101
# No results found for ISIN XS0611590885
# No results found for ISIN XS0611590299
# Could not obtain prospectus for RmsId 355, ScoringDate 2021-06-29 00:00:00
# Finished processing RmsId 355.
# Prospectus for RmsId 357 already exists at ../data/processed/357/as_expected, skipping.
# Output folder for RmsId 358 exists, proceeding without deleting existing files.
# No results found for ISIN SE0010830950
# No results found for ISIN SE0005878535
# Could not obtain prospectus for RmsId 358, ScoringDate 2021-12-08 00:00:00
# Finished processing RmsId 358.
# Prospectus for RmsId 361 already exists at ../data/processed/361/as_expected, skipping.
# Prospectus for RmsId 364 already exists at ../data/processed/364/as_expected, skipping.
# Output folder for RmsId 373 exists, proceeding without deleting existing files.
# No results found for ISIN SE0013234325
# Could not obtain prospectus for RmsId 373, ScoringDate 2021-07-18 00:00:00
# Finished processing RmsId 373.
# Output folder for RmsId 382 exists, proceeding without deleting existing files.
# No results found for ISIN XS2434783911
# No results found for ISIN XS2434794363
# No results found for ISIN XS2010027881
# No results found for ISIN XS2010029317
# No results found for ISIN XS2111946930
# No results found for ISIN XS2111947748
# No results found for ISIN XS2111947318
# No results found for ISIN XS2758078930
# No results found for ISIN XS2759982650
# No results found for ISIN XS2758099779
# No results found for ISIN XS2758100296
# No results found for ISIN XS1843437200
# No results found for ISIN XS1843436731
# No results found for ISIN XS2919880679
# No results found for ISIN XS1647814968
# No results found for ISIN XS1647815775
# No results found for ISIN XS1453499664
# No results found for ISIN XS1223776441
# No results found for ISIN XS1223777175
# No results found for ISIN XS0992294388
# Could not obtain prospectus for RmsId 382, ScoringDate 2022-01-12 00:00:00
# No results found for ISIN XS2434783911
# No results found for ISIN XS2434794363
# No results found for ISIN XS2758078930
# No results found for ISIN XS2759982650
# No results found for ISIN XS2758099779
# No results found for ISIN XS2758100296
# No results found for ISIN XS2010027881
# No results found for ISIN XS2010029317
# No results found for ISIN XS2919880679
# No results found for ISIN XS2111946930
# No results found for ISIN XS2111947748
# No results found for ISIN XS2111947318
# No results found for ISIN XS1843437200
# No results found for ISIN XS1843436731
# No results found for ISIN XS1647814968
# No results found for ISIN XS1647815775
# No results found for ISIN XS1453499664
# No results found for ISIN XS1223776441
# No results found for ISIN XS1223777175
# No results found for ISIN XS0992294388
# Could not obtain prospectus for RmsId 382, ScoringDate 2022-10-31 00:00:00
# Finished processing RmsId 382.
# Output folder for RmsId 385 exists, proceeding without deleting existing files.
# No results found for ISIN XS1071440991
# No results found for ISIN XS0633050736
# Could not obtain prospectus for RmsId 385, ScoringDate 2021-03-25 00:00:00
# Finished processing RmsId 385.
# Prospectus for RmsId 398 already exists at ../data/processed/398/as_expected, skipping.
# Output folder for RmsId 400 exists, proceeding without deleting existing files.
# No results found for ISIN XS1879638697
# No results found for ISIN XS0894469880
# Could not obtain prospectus for RmsId 400, ScoringDate 2022-02-07 00:00:00
# Finished processing RmsId 400.
# Prospectus for RmsId 407 already exists at ../data/processed/407/as_expected, skipping.
# Output folder for RmsId 413 exists, proceeding without deleting existing files.
# No results found for ISIN XS2338563716
# No results found for ISIN XS2230739059
# No results found for ISIN XS2818818507
# No results found for ISIN XS1622391552
# No results found for ISIN XS1622392014
# No results found for ISIN XS1622391636
# No results found for ISIN XS1262167775
# No results found for ISIN XS1262174557
# No results found for ISIN XS0749351093
# Could not obtain prospectus for RmsId 413, ScoringDate 2021-04-27 00:00:00
# Finished processing RmsId 413.
# Prospectus for RmsId 430 already exists at ../data/processed/430/as_expected, skipping.
# Prospectus for RmsId 433 already exists at ../data/processed/433/as_expected, skipping.
# Output folder for RmsId 435 exists, proceeding without deleting existing files.
# No results found for ISIN XS1582206956
# No results found for ISIN XS1202910763
# No results found for ISIN XS0605209849
# Could not obtain prospectus for RmsId 435, ScoringDate 2021-12-07 00:00:00
# Finished processing RmsId 435.
# Output folder for RmsId 438 exists, proceeding without deleting existing files.
# No results found for ISIN XS1080255067
# No results found for ISIN XS1067602331
# No results found for ISIN XS0928190940
# No results found for ISIN XS0556268471
# Could not obtain prospectus for RmsId 438, ScoringDate 2021-11-22 00:00:00
# Finished processing RmsId 438.
# Prospectus for RmsId 441 already exists at ../data/processed/441/as_expected, skipping.
# Output folder for RmsId 451 exists, proceeding without deleting existing files.
# No results found for ISIN XS2656464844
# No results found for ISIN XS1684813493
# No results found for ISIN XS1684812339
# No results found for ISIN XS1179900102
# No results found for ISIN XS0752223940
# Could not obtain prospectus for RmsId 451, ScoringDate 2022-02-18 00:00:00
# Finished processing RmsId 451.
# Output folder for RmsId 453 exists, proceeding without deleting existing files.
# No results found for ISIN XS2294856286
# No results found for ISIN XS2258560361
# No results found for ISIN XS1267053103
# No results found for ISIN XS0612409184
# Could not obtain prospectus for RmsId 453, ScoringDate 2022-02-21 00:00:00
# Finished processing RmsId 453.
# Output folder for RmsId 454 exists, proceeding without deleting existing files.
# No results found for ISIN XS1512830982
# No results found for ISIN XS1513079571
# No results found for ISIN XS1267463856
# No results found for ISIN XS1093814116
# Could not obtain prospectus for RmsId 454, ScoringDate 2022-03-21 00:00:00
# No results found for ISIN XS1512830982
# No results found for ISIN XS1513079571
# No results found for ISIN XS1267463856
# No results found for ISIN XS1093814116
# Could not obtain prospectus for RmsId 454, ScoringDate 2023-01-27 00:00:00
# No results found for ISIN XS1512830982
# No results found for ISIN XS1513079571
# No results found for ISIN XS1267463856
# No results found for ISIN XS1093814116
# Could not obtain prospectus for RmsId 454, ScoringDate 2024-10-17 00:00:00
# Finished processing RmsId 454.
# Output folder for RmsId 458 exists, proceeding without deleting existing files.
# No results found for ISIN US060335AB23
# No results found for ISIN XS2690055996
# No results found for ISIN XS2112335752
# No results found for ISIN XS2112340679
# No results found for ISIN US060335AA40
# No results found for ISIN XS1642700766
# Could not obtain prospectus for RmsId 458, ScoringDate 2022-02-28 00:00:00
# Finished processing RmsId 458.
# Output folder for RmsId 470 exists, proceeding without deleting existing files.
# No results found for ISIN XS2111944133
# No results found for ISIN XS2111944992
# No results found for ISIN XS2908089878
# No results found for ISIN XS1577948174
# No results found for ISIN XS1577950154
# No results found for ISIN XS0982711045
# No results found for ISIN XS0982712951
# Could not obtain prospectus for RmsId 470, ScoringDate 2022-02-28 00:00:00
# Finished processing RmsId 470.
# Output folder for RmsId 471 exists, proceeding without deleting existing files.
# No results found for ISIN XS2357281174
# No results found for ISIN XS1497527736
# No results found for ISIN XS0954676283
# Could not obtain prospectus for RmsId 471, ScoringDate 2021-06-18 00:00:00
# Finished processing RmsId 471.
# Prospectus for RmsId 476 already exists at ../data/processed/476/as_expected, skipping.
# Prospectus for RmsId 477 already exists at ../data/processed/477/as_expected, skipping.
# Prospectus for RmsId 504 already exists at ../data/processed/504/as_expected, skipping.
# Prospectus for RmsId 509 already exists at ../data/processed/509/as_expected, skipping.
# Output folder for RmsId 517 exists, proceeding without deleting existing files.
# No results found for ISIN XS1791484394
# No results found for ISIN XS1791484717
# Could not obtain prospectus for RmsId 517, ScoringDate 2021-02-04 00:00:00
# Finished processing RmsId 517.
# Prospectus for RmsId 519 already exists at ../data/processed/519/as_expected, skipping.
# Output folder for RmsId 612 exists, proceeding without deleting existing files.
# No results found for ISIN XS2389334124
# Could not obtain prospectus for RmsId 612, ScoringDate 2021-10-04 00:00:00
# No results found for ISIN XS2389334124
# Could not obtain prospectus for RmsId 612, ScoringDate 2023-11-15 00:00:00
# Finished processing RmsId 612.
# Output folder for RmsId 615 exists, proceeding without deleting existing files.
# No results found for ISIN XS2189592616
# Could not obtain prospectus for RmsId 615, ScoringDate 2022-02-21 00:00:00
# Finished processing RmsId 615.
# Prospectus for RmsId 624 already exists at ../data/processed/624/as_expected, skipping.
# Prospectus for RmsId 625 already exists at ../data/processed/625/as_expected, skipping.
# Prospectus for RmsId 629 already exists at ../data/processed/629/as_expected, skipping.
# Prospectus for RmsId 630 already exists at ../data/processed/630/as_expected, skipping.
# Prospectus for RmsId 640 already exists at ../data/processed/640/as_expected, skipping.
# Prospectus for RmsId 641 already exists at ../data/processed/641/as_expected, skipping.
# Prospectus for RmsId 642 already exists at ../data/processed/642/as_expected, skipping.
# Prospectus for RmsId 643 already exists at ../data/processed/643/as_expected, skipping.
# Prospectus for RmsId 657 already exists at ../data/processed/657/as_expected, skipping.
# Prospectus for RmsId 668 already exists at ../data/processed/668/as_expected, skipping.
# Output folder for RmsId 756 exists, proceeding without deleting existing files.
# No results found for ISIN XS2436313196
# No results found for ISIN XS2436314160
# Could not obtain prospectus for RmsId 756, ScoringDate 2022-02-14 00:00:00
# No results found for ISIN XS2436313196
# No results found for ISIN XS2436314160
# Could not obtain prospectus for RmsId 756, ScoringDate 2023-01-06 00:00:00
# Finished processing RmsId 756.
# Output folder for RmsId 767 exists, proceeding without deleting existing files.
# No results found for ISIN XS2445836286
# No results found for ISIN XS2445840809
# No results found for ISIN CERVIM_ADDON
# No results found for ISIN XS0876813600
# No results found for ISIN XS0876835595
# Could not obtain prospectus for RmsId 767, ScoringDate 2022-02-10 00:00:00
# No results found for ISIN XS2445836286
# No results found for ISIN XS2445840809
# No results found for ISIN CERVIM_ADDON
# No results found for ISIN XS0876813600
# No results found for ISIN XS0876835595
# Could not obtain prospectus for RmsId 767, ScoringDate 2022-09-06 00:00:00
# Finished processing RmsId 767.
# Output folder for RmsId 789 exists, proceeding without deleting existing files.
# No results found for ISIN XS1713466222
# No results found for ISIN XS1713466149
# No results found for ISIN XS1028950886
# Could not obtain prospectus for RmsId 789, ScoringDate 2022-10-01 00:00:00
# Finished processing RmsId 789.
# Output folder for RmsId 808 exists, proceeding without deleting existing files.
# No results found for ISIN XS2397448346
# No results found for ISIN XS2397447538
# No results found for ISIN XS2397447025
# Could not obtain prospectus for RmsId 808, ScoringDate 2022-06-22 00:00:00
# Finished processing RmsId 808.
# Output folder for RmsId 813 exists, proceeding without deleting existing files.
# No results found for ISIN XS2399981435
# Could not obtain prospectus for RmsId 813, ScoringDate 2022-02-27 00:00:00
# Finished processing RmsId 813.
# Output folder for RmsId 845 exists, proceeding without deleting existing files.
# No results found for ISIN XS1577963058
# Could not obtain prospectus for RmsId 845, ScoringDate 2022-11-09 00:00:00
# Finished processing RmsId 845.
# Prospectus for RmsId 887 already exists at ../data/processed/887/as_expected, skipping.
# Output folder for RmsId 917 exists, proceeding without deleting existing files.
# No results found for ISIN FR001400EFQ6
# No results found for ISIN US28504KAA51
# No results found for ISIN FR0014003S56
# No results found for ISIN FR0013534351
# No results found for ISIN FR0013534336
# No results found for ISIN FR001400SMT6
# No results found for ISIN FR001400SMS8
# No results found for ISIN FR001400SMR0
# No results found for ISIN FR0013464922
# No results found for ISIN FR0013445137
# No results found for ISIN FR0013367612
# No results found for ISIN FR0013152899
# No results found for ISIN FR0013060209
# No results found for ISIN FR0012199065
# No results found for ISIN FR0011697028
# No results found for ISIN FR0011700293
# No results found for ISIN FR0011697010
# No results found for ISIN US268317AM62
# No results found for ISIN FR0011565555
# No results found for ISIN FR0011401751
# No results found for ISIN FR0011401728
# No results found for ISIN US268317AF12
# No results found for ISIN FR0011318658
# No results found for ISIN FR0011182641
# No results found for ISIN XS0557897203
# No results found for ISIN FR0010913178
# No results found for ISIN XS0495756537
# No results found for ISIN FR0010800540
# No results found for ISIN XS0441402681
# No results found for ISIN FR0010660043
# No results found for ISIN XS0367001228
# Could not obtain prospectus for RmsId 917, ScoringDate 2022-08-11 00:00:00
# Finished processing RmsId 917.
# Output folder for RmsId 920 exists, proceeding without deleting existing files.
# No results found for ISIN US13323AAB61
# Could not obtain prospectus for RmsId 920, ScoringDate 2022-04-27 00:00:00
# Finished processing RmsId 920.
# Output folder for RmsId 935 exists, proceeding without deleting existing files.
# No results found for ISIN XS2484502823
# No results found for ISIN XS2615584328
# Could not obtain prospectus for RmsId 935, ScoringDate 2022-06-01 00:00:00
# Finished processing RmsId 935.
# Output folder for RmsId 936 exists, proceeding without deleting existing files.
# No results found for ISIN FI4000523550
# No results found for ISIN FI4000562202
# Could not obtain prospectus for RmsId 936, ScoringDate 2022-06-01 00:00:00
# Finished processing RmsId 936.
# Prospectus for RmsId 952 already exists at ../data/processed/952/as_expected, skipping.
# Prospectus for RmsId 977 already exists at ../data/processed/977/as_expected, skipping.
# Output folder for RmsId 988 exists, proceeding without deleting existing files.
# No results found for ISIN US497864AA68
# No results found for ISIN US49835DAA72
# Could not obtain prospectus for RmsId 988, ScoringDate 2022-05-04 00:00:00
# Finished processing RmsId 988.
# Output folder for RmsId 1026 exists, proceeding without deleting existing files.
# No results found for ISIN XS2470988101
# No results found for ISIN XS0717069073
# Could not obtain prospectus for RmsId 1026, ScoringDate 2023-03-23 00:00:00
# Finished processing RmsId 1026.
# Prospectus for RmsId 1044 already exists at ../data/processed/1044/as_expected, skipping.
# Output folder for RmsId 1047 exists, proceeding without deleting existing files.
# No results found for ISIN US36168QAP90
# No results found for ISIN US36168QAN43
# No results found for ISIN US36168QAM69
# No results found for ISIN US36168QAL86
# No results found for ISIN US36168QAQ73
# No results found for ISIN US36168QAK04
# No results found for ISIN US36168QAJ31
# No results found for ISIN US36168QAF19
# No results found for ISIN US36168QAE44
# Could not obtain prospectus for RmsId 1047, ScoringDate 2022-05-24 00:00:00
# Finished processing RmsId 1047.
# Prospectus for RmsId 1065 already exists at ../data/processed/1065/as_expected, skipping.
# Prospectus for RmsId 1122 already exists at ../data/processed/1122/as_expected, skipping.
# Output folder for RmsId 1144 exists, proceeding without deleting existing files.
# No results found for ISIN XS2067263850
# No results found for ISIN XS2067265392
# Could not obtain prospectus for RmsId 1144, ScoringDate 2024-01-24 00:00:00
# Finished processing RmsId 1144.
# Prospectus for RmsId 1145 already exists at ../data/processed/1145/as_expected, skipping.
# Prospectus for RmsId 1162 already exists at ../data/processed/1162/as_expected, skipping.
# Output folder for RmsId 1197 exists, proceeding without deleting existing files.
# No results found for ISIN XS2434702853
# No results found for ISIN XS2434701616
# No results found for ISIN XS2278566299
# No results found for ISIN XS2267889991
# No results found for ISIN XS1688199949
# No results found for ISIN XS1528093799
# No results found for ISIN XS1327504087
# No results found for ISIN XS1316567343
# No results found for ISIN XS1316569638
# No results found for ISIN IT0005108490
# No results found for ISIN XS0986174851
# No results found for ISIN XS0542534192
# No results found for ISIN XS0193945655
# No results found for ISIN XS0193942124
# Could not obtain prospectus for RmsId 1197, ScoringDate 2022-10-12 00:00:00
# Finished processing RmsId 1197.
# Output folder for RmsId 1199 exists, proceeding without deleting existing files.
# No results found for ISIN XS2748964850
# No results found for ISIN XS2821787962
# No results found for ISIN XS2821788770
# No results found for ISIN XS2548508881
# No results found for ISIN XS2548508451
# Could not obtain prospectus for RmsId 1199, ScoringDate 2024-01-10 00:00:00
# Finished processing RmsId 1199.
# Output folder for RmsId 1207 exists, proceeding without deleting existing files.
# No results found for ISIN XS2815887372
# No results found for ISIN XS1216020161
# No results found for ISIN XS1216019585
# Could not obtain prospectus for RmsId 1207, ScoringDate 2022-10-04 00:00:00
# Finished processing RmsId 1207.
# Prospectus for RmsId 1211 already exists at ../data/processed/1211/as_expected, skipping.
# Output folder for RmsId 1224 exists, proceeding without deleting existing files.
# No results found for ISIN XS2250349581
# No results found for ISIN US44984WAH07
# No results found for ISIN XS2587558474
# No results found for ISIN XS2762276967
# No results found for ISIN US44984WAJ62
# No results found for ISIN XS1843437549
# No results found for ISIN XS1577947440
# No results found for ISIN XS1405769990
# No results found for ISIN US44986UAD19
# No results found for ISIN XS1117296209
# No results found for ISIN XS0982710740
# No results found for ISIN US44986UAC36
# No results found for ISIN XS0928189777
# No results found for ISIN XS0928189934
# No results found for ISIN XS0744133074
# No results found for ISIN XS0744132936
# No results found for ISIN XS0508553764
# No results found for ISIN XS0242945367
# Could not obtain prospectus for RmsId 1224, ScoringDate 2021-11-02 00:00:00
# No results found for ISIN US44984WAH07
# No results found for ISIN XS2587558474
# No results found for ISIN XS2762276967
# No results found for ISIN US44984WAJ62
# No results found for ISIN XS2250349581
# No results found for ISIN XS1843437549
# No results found for ISIN XS1577947440
# No results found for ISIN XS1405769990
# No results found for ISIN US44986UAD19
# No results found for ISIN XS1117296209
# No results found for ISIN XS0982710740
# No results found for ISIN US44986UAC36
# No results found for ISIN XS0928189777
# No results found for ISIN XS0928189934
# No results found for ISIN XS0744133074
# No results found for ISIN XS0744132936
# No results found for ISIN XS0508553764
# No results found for ISIN XS0242945367
# Could not obtain prospectus for RmsId 1224, ScoringDate 2023-02-07 00:00:00
# Finished processing RmsId 1224.
# Output folder for RmsId 1231 exists, proceeding without deleting existing files.
# No results found for ISIN NO0010874548
# No results found for ISIN XS1180324037
# Could not obtain prospectus for RmsId 1231, ScoringDate 2022-08-10 00:00:00
# Finished processing RmsId 1231.
# Prospectus for RmsId 1240 already exists at ../data/processed/1240/as_expected, skipping.
# Output folder for RmsId 1249 exists, proceeding without deleting existing files.
# No results found for ISIN US44810RAA68
# No results found for ISIN US88827AAA16
# Could not obtain prospectus for RmsId 1249, ScoringDate 2022-09-02 00:00:00
# Finished processing RmsId 1249.
# Prospectus for RmsId 1277 already exists at ../data/processed/1277/as_expected, skipping.
# Output folder for RmsId 1338 exists, proceeding without deleting existing files.
# No results found for ISIN PTEDPZOM0011
# No results found for ISIN PTEDPSOM0002
# No results found for ISIN PTEDP4OM0025
# No results found for ISIN PTEDPYOM0020
# No results found for ISIN PTEDPXOM0021
# No results found for ISIN PTEDPROM0029
# No results found for ISIN PTEDPLOM0017
# No results found for ISIN PTEDPKOM0034
# No results found for ISIN PTEDPUOM0024
# Could not obtain prospectus for RmsId 1338, ScoringDate 2024-06-03 00:00:00
# Finished processing RmsId 1338.
# Output folder for RmsId 1479 exists, proceeding without deleting existing files.
# No results found for ISIN US85529VAA26
# Could not obtain prospectus for RmsId 1479, ScoringDate 2023-03-19 00:00:00
# Finished processing RmsId 1479.
# Output folder for RmsId 1485 exists, proceeding without deleting existing files.
# No results found for ISIN XS2798887076
# Could not obtain prospectus for RmsId 1485, ScoringDate 2023-03-05 00:00:00
# Finished processing RmsId 1485.
# Prospectus for RmsId 1509 already exists at ../data/processed/1509/as_expected, skipping.
# Output folder for RmsId 1511 exists, proceeding without deleting existing files.
# No results found for ISIN FR001400Q5V0
# No results found for ISIN FR001400OL29
# No results found for ISIN FR001400H0F5
# No results found for ISIN FR0013354297
# No results found for ISIN FR0013176294
# No results found for ISIN FR0011376201
# No results found for ISIN FR0010465427
# Could not obtain prospectus for RmsId 1511, ScoringDate 2024-06-05 00:00:00
# Finished processing RmsId 1511.
# Output folder for RmsId 1565 exists, proceeding without deleting existing files.
# No results found for ISIN XS0860995355
# No results found for ISIN XS0860984235
# Could not obtain prospectus for RmsId 1565, ScoringDate 2023-04-26 00:00:00
# Finished processing RmsId 1565.
# Output folder for RmsId 1596 exists, proceeding without deleting existing files.
# No results found for ISIN XS2620212386
# No results found for ISIN XS2241097687
# Could not obtain prospectus for RmsId 1596, ScoringDate 2023-05-09 00:00:00
# Finished processing RmsId 1596.
# Output folder for RmsId 1629 exists, proceeding without deleting existing files.
# No results found for ISIN XS2637969341
# No results found for ISIN XS2842976289
# No results found for ISIN XS2842976875
# No results found for ISIN XS2085860844
# Could not obtain prospectus for RmsId 1629, ScoringDate 2023-06-11 00:00:00
# No results found for ISIN XS2842976289
# No results found for ISIN XS2842976875
# No results found for ISIN XS2637969341
# No results found for ISIN XS2085860844
# Could not obtain prospectus for RmsId 1629, ScoringDate 2024-06-06 00:00:00
# Finished processing RmsId 1629.
# Output folder for RmsId 1720 exists, proceeding without deleting existing files.
# Exception occurred while downloading ISIN XS2937255193: HTTPConnectionPool(host='localhost', port=57823): Read timed out. (read timeout=120)
# Exception occurred while downloading ISIN XS2282606578: HTTPConnectionPool(host='localhost', port=57823): Read timed out. (read timeout=120)
# No results found for ISIN XS2256949749
# No results found for ISIN XS1205716720
# No results found for ISIN US05330KAA34
# No results found for ISIN ES0211845211
# Could not obtain prospectus for RmsId 1720, ScoringDate 2023-08-28 00:00:00
# Finished processing RmsId 1720.
# Prospectus for RmsId 1727 already exists at ../data/processed/1727/as_expected, skipping.
# Output folder for RmsId 1733 exists, proceeding without deleting existing files.
# No results found for ISIN FR001400KKX9
# Could not obtain prospectus for RmsId 1733, ScoringDate 2023-09-20 00:00:00
# Finished processing RmsId 1733.
# Output folder for RmsId 1754 exists, proceeding without deleting existing files.
# No results found for ISIN FI4000541685
# No results found for ISIN FI4000507876
# Could not obtain prospectus for RmsId 1754, ScoringDate 2024-06-19 00:00:00
# Finished processing RmsId 1754.
# Output folder for RmsId 1768 exists, proceeding without deleting existing files.
# No results found for ISIN XS1748432876
# Could not obtain prospectus for RmsId 1768, ScoringDate 2023-10-17 00:00:00
# Finished processing RmsId 1768.
# Prospectus for RmsId 1769 already exists at ../data/processed/1769/as_expected, skipping.
# Prospectus for RmsId 1789 already exists at ../data/processed/1789/as_expected, skipping.
# Output folder for RmsId 1793 exists, proceeding without deleting existing files.
# No results found for ISIN XS2310951103
# No results found for ISIN XS1961852750
# No results found for ISIN XS1383922876
# No results found for ISIN XS1117298676
# No results found for ISIN US803071AC31
# No results found for ISIN XS0615932331
# No results found for ISIN USA35868AA59
# No results found for ISIN US803071AA74
# No results found for ISIN XS0442348073
# Could not obtain prospectus for RmsId 1793, ScoringDate 2023-12-19 00:00:00
# Finished processing RmsId 1793.
# Prospectus for RmsId 1794 already exists at ../data/processed/1794/as_expected, skipping.
# Output folder for RmsId 1795 exists, proceeding without deleting existing files.
# No results found for ISIN XS2919902820
# No results found for ISIN XS2404291010
# Could not obtain prospectus for RmsId 1795, ScoringDate 2023-12-19 00:00:00
# Finished processing RmsId 1795.
# Output folder for RmsId 1807 exists, proceeding without deleting existing files.
# No results found for ISIN XS2250153769
# No results found for ISIN XS2250155467
# No results found for ISIN XS2250154494
# No results found for ISIN XS1308300059
# No results found for ISIN XS1308316568
# No results found for ISIN XS1263891910
# No results found for ISIN XS1028960331
# No results found for ISIN XS0885613769
# No results found for ISIN XS0652913806
# Could not obtain prospectus for RmsId 1807, ScoringDate 2023-11-27 00:00:00
# Finished processing RmsId 1807.
# Output folder for RmsId 1821 exists, proceeding without deleting existing files.
# No results found for ISIN XS2798174434
# No results found for ISIN XS2417486771
# Could not obtain prospectus for RmsId 1821, ScoringDate 2023-12-19 00:00:00
# Finished processing RmsId 1821.
# Prospectus for RmsId 1897 already exists at ../data/processed/1897/as_expected, skipping.
# Output folder for RmsId 1900 exists, proceeding without deleting existing files.
# No results found for ISIN XS2750308483
# No results found for ISIN XS2864439158
# No results found for ISIN XS2301390089
# No results found for ISIN XS1645722262
# No results found for ISIN XS1558491855
# Could not obtain prospectus for RmsId 1900, ScoringDate 2024-01-27 00:00:00
# Finished processing RmsId 1900.
# Output folder for RmsId 1931 exists, proceeding without deleting existing files.
# No results found for ISIN XS2778385240
# No results found for ISIN XS2563353361
# No results found for ISIN XS2293075680
# No results found for ISIN XS2293681685
# No results found for ISIN XS2010036874
# No results found for ISIN XS1720192696
# No results found for ISIN XS0426738976
# No results found for ISIN XS0426739354
# Could not obtain prospectus for RmsId 1931, ScoringDate 2024-02-26 00:00:00
# Finished processing RmsId 1931.
# Output folder for RmsId 2004 exists, proceeding without deleting existing files.
# No results found for ISIN XS2351480996
# No results found for ISIN XS2351480640
# Could not obtain prospectus for RmsId 2004, ScoringDate 2024-05-14 00:00:00
# Finished processing RmsId 2004.
# Output folder for RmsId 2097 exists, proceeding without deleting existing files.
# No results found for ISIN XS2857868942
# Could not obtain prospectus for RmsId 2097, ScoringDate 2024-06-20 00:00:00
# Finished processing RmsId 2097.
# Output folder for RmsId 2109 exists, proceeding without deleting existing files.
# No results found for ISIN XS2854277626
# No results found for ISIN XS2854278863
# Could not obtain prospectus for RmsId 2109, ScoringDate 2024-07-02 00:00:00
# Finished processing RmsId 2109.
# Output folder for RmsId 2145 exists, proceeding without deleting existing files.
# No results found for ISIN XS1321149434
# Could not obtain prospectus for RmsId 2145, ScoringDate 2024-08-21 00:00:00
# Finished processing RmsId 2145.
# Output folder for RmsId 2154 exists, proceeding without deleting existing files.
# No results found for ISIN XS2910523716
# Could not obtain prospectus for RmsId 2154, ScoringDate 2024-09-11 00:00:00
# Finished processing RmsId 2154.
